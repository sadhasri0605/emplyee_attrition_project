# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Direct link to the dataset file
dataset_url = 'https://raw.githubusercontent.com/Thangam-11/Acme-Employee-Attrition-Analysis-and-Prediction/main/Attrition%20Dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv'

# Load the dataset into a DataFrame
data_attr = pd.read_csv(dataset_url)

# %%
data_attr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
# check the dataset shape

data_attr.shape
# Out:
# (1470, 35)

# %% [markdown]
# In all we have 34 features consisting of both the categorical as well as the numerical features. The target variable is the 'Attrition' of the employee which can be either a Yes or a No.

# %%
# check the null values in the dataset
data_attr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Data Exploration:
#     Explore data distributions, identify outliers, and handle missing values using data visualization libarary
#  Creating the histogram and box plots

# %%
Numerical = [feature for feature in data_attr.columns if data_attr[feature].dtype != "O"]
Catgorical =  [feature for feature in data_attr.columns if data_attr[feature].dtype == "O"]

# %%
Numerical
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %% [markdown]
# # 1.Univariate analysis:
#
# In this section I have done the univariate analysis i.e. I have analysed the range or distribution of the values that various features take. To better analyze the results I have plotted various graphs and visualizations wherever necessary.

# %%
def plot(data_attr,column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=data_attr, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=data_attr, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

# %%
for i in (['Age','DailyRate','DistanceFromHome', 'Education', 'EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','HourlyRate','JobInvolvement','JobLevel','JobSatisfaction','MonthlyIncome','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours', 'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']):
    plot(data_attr,i)

# %%
data_attr['JobSatisfaction'].value_counts()
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64

# %%
ax_over = sns.countplot(x='Attrition', data=data_attr)
plt.title('Count of Attrition')
plt.xlabel('BusinessTravel')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax_over = sns.countplot(x='BusinessTravel', data=data_attr)
plt.title('Count of BusinessTravel')
plt.xlabel('BusinessTravel')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax_over = sns.countplot(x='Department', data=data_attr)
plt.title('Count of Department')
plt.xlabel('Department')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax_over = sns.countplot(x='EducationField', data=data_attr)
plt.title('Count of EducationField')
plt.xlabel('EducationField')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax_over = sns.countplot(x='Gender', data=data_attr)
plt.title('Count of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax_over = sns.countplot(x='JobRole', data=data_attr)
plt.title('Count of JobRole')
plt.xlabel('JobRole')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax = sns.countplot(x='MaritalStatus', data=data_attr)
plt.title('Count of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
ax_over = sns.countplot(x='OverTime', data=data_attr)
plt.title('Count of OverTime')
plt.xlabel('OverTime')
plt.ylabel('Count')

# Adding annotations
for p in ax_over.patches:
    ax_over.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %% [markdown]
# # 2.Bivariate analysis

# %% [markdown]
# #

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Attrition', y='Age',data = data_attr ,ec = "black",palette="Set2")
plt.title("Attrition vs Age", weight="bold",fontsize=20, pad=20)
plt.ylabel("Age", weight="bold", fontsize=15)
plt.xlabel("Attrition", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Attrition', y='Age',data = data_attr ,ec = "black",palette="Set2")
plt.title("Attrition vs Age", weight="bold",fontsize=20, pad=20)
plt.ylabel("Age", weight="bold", fontsize=15)
plt.xlabel("Attrition", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
data_attr.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='BusinessTravel', y='Age',hue='Attrition',data = data_attr ,ec = "black",palette="Set2")
plt.title("Age vs BusinessTravel", weight="bold",fontsize=20, pad=20)
plt.ylabel("BusinessTravel", weight="bold", fontsize=15)
plt.xlabel("Age", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The above plot clearly shows that most of the people belong to the 'Travel_Rarely' class. This indicates that most of the people did not have a job which asked them for frequent travelling.

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Department', y='MonthlyIncome',hue='Attrition',data = data_attr ,ec = "black",palette="Set2")
plt.title("Department vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("Department", weight="bold", fontsize=15)
plt.xlabel("MonthlyIncome", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Education', y='MonthlyIncome',hue='Attrition',data = data_attr ,ec = "black",palette="Set2")
plt.title("Education vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("Education", weight="bold", fontsize=15)
plt.xlabel("MonthlyIncome", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='EducationField', y='MonthlyIncome',hue='Attrition',data = data_attr ,ec = "black",palette="Set2")
plt.title("EducationField vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("EducationField", weight="bold", fontsize=15)
plt.xlabel("MonthlyIncome", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
total_income= sum(data_attr['MonthlyIncome'])
total_income
# Out:
# 9559309

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Attrition', y='JobInvolvement',data = data_attr ,ec = "black",palette="Set2")
plt.title("Attrition vs JobInvolvement", weight="bold",fontsize=20, pad=20)
plt.ylabel("JobInvolvement", weight="bold", fontsize=15)
plt.xlabel("Attrition", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Attrition', y='EnvironmentSatisfaction',data = data_attr ,ec = "black",palette="Set2")
plt.title("Attrition vs JobInvolvement", weight="bold",fontsize=20, pad=20)
plt.ylabel("JobInvolvement", weight="bold", fontsize=15)
plt.xlabel("Attrition", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobLevel', y='MonthlyIncome',hue = 'Attrition',data = data_attr ,ec = "black",palette="Set2")
plt.title("JobLevel vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("JobLevel", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobRole', y='MonthlyIncome',data = data_attr ,ec = "black",palette="Set2")
plt.title("JobRole vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("JobRole", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("JobSatisfaction vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("JobSatisfaction", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='Gender', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("Gender vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("Gender", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='MaritalStatus', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("MaritalStatus vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("MaritalStatus", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='RelationshipSatisfaction', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("RelationshipSatisfaction vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("RelationshipSatisfaction", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='NumCompaniesWorked', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("NumCompaniesWorked vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("NumCompaniesWorked", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='TotalWorkingYears', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,order = data_attr['TotalWorkingYears'].value_counts().index[:15],ec = "black",palette="Set2")
plt.title("TotalWorkingYears vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("TotalWorkingYears", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='WorkLifeBalance', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("WorkLifeBalance vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("WorkLifeBalance", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='YearsAtCompany', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,order = data_attr['YearsAtCompany'].value_counts().index[:20],ec = "black",palette="Set2")
plt.title("YearsAtCompany vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("YearsAtCompany", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='YearsInCurrentRole', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("YearsInCurrentRole vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("YearsInCurrentRole", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='YearsSinceLastPromotion', y='MonthlyIncome',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("YearsSinceLastPromotion vs MonthlyIncome", weight="bold",fontsize=20, pad=20)
plt.ylabel("MonthlyIncome", weight="bold", fontsize=15)
plt.xlabel("YearsSinceLastPromotion", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='YearsSinceLastPromotion',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("JobSatisfaction vs YearsSinceLastPromotion", weight="bold",fontsize=20, pad=20)
plt.ylabel("YearsSinceLastPromotion", weight="bold", fontsize=15)
plt.xlabel("YearsSinceLastPromotion", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='YearsSinceLastPromotion' ,data = data_attr,hue = 'Attrition'  ,ec = "black",palette="Set2")
plt.title("JobSatisfaction vs YearsSinceLastPromotion", weight="bold",fontsize=20, pad=20)
plt.ylabel("YearsSinceLastPromotion", weight="bold", fontsize=15)
plt.xlabel("YearsSinceLastPromotion", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='TotalWorkingYears',hue = 'Attrition' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("JobSatisfaction vs YearsSinceLastPromotion", weight="bold",fontsize=20, pad=20)
plt.ylabel("TotalWorkingYears", weight="bold", fontsize=15)
plt.xlabel("JobSatisfaction", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='YearsAtCompany' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("JobSatisfaction vs YearsAtCompany", weight="bold",fontsize=20, pad=20)
plt.ylabel("YearsAtCompany", weight="bold", fontsize=15)
plt.xlabel("JobSatisfaction", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='YearsInCurrentRole' ,data = data_attr ,ec = "black",palette="Set2")
plt.title("JobSatisfaction vs YearsInCurrentRole", weight="bold",fontsize=20, pad=20)
plt.ylabel("YearsInCurrentRole", weight="bold", fontsize=15)
plt.xlabel("JobSatisfaction", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.barplot(x='JobSatisfaction', y='YearsWithCurrManager' ,data = data_attr, hue = 'Attrition',ec = "black",palette="Set2")
plt.title("JobSatisfaction vs YearsWithCurrManager", weight="bold",fontsize=20, pad=20)
plt.ylabel("YearsWithCurrManager", weight="bold", fontsize=15)
plt.xlabel("JobSatisfaction", weight="bold", fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 3.Multivariate analysis

# %%
Numerical
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
Numerical_columns = ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
core = data_attr[Numerical_columns].corr()

# %%
plt.figure(figsize=(24, 10))
sns.heatmap(core, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
data_attr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data_attr['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %% [markdown]
# # Feature Encoding:

# %%
data_attr['Attrition_numeric'] = data_attr['Attrition'].map({
    'No' : 0,
    'Yes' : 1

})

# %%
data_attr['Gender_numeric'] = data_attr['Gender'].map({
    'Male' : 0,
    'Female' : 1

})

# %%
data_attr['MaritalStatus_numeric'] = data_attr['MaritalStatus'].map({
    'Married' : 0,
    'Single' : 1,
    'Divorced':2


})

# %%
data_attr['OverTime_numeric'] = data_attr['OverTime'].map({
    'No' : 0,
    'Yes' : 1

})

# %%
data_attr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  TrainingTimesLastYear WorkLifeBalance  \
# 0                  1  ...                      0               1
# 1                  2  ...                      3               3
# 2                  4  ...                      3               3
# 3                  5  ...                      3               3
# 4                  7  ...                      3               3
# ...              ...  ...                    ...             ...
# 1465            2061  ...                      3               3
# 1466            2062  ...                      5               3
# 1467            2064  ...                      0               3
# 1468            2065  ...                      3               2
# 1469            2068  ...                      3               4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#      YearsWithCurrManager  Attrition_numeric Gender_numeric  \
# 0                       5                  1              1
# 1                       7                  0              0
# 2                       0                  1              0
# 3                       0                  0              1
# 4                       2                  0              0
# ...                   ...                ...            ...
# 1465                    3                  0              0
# 1466                    7                  0              0
# 1467                    3                  0              0
# 1468                    8                  0              0
# 1469                    2                  0              0
#
#       MaritalStatus_numeric  OverTime_numeric
# 0                         1                 1
# 1                         0                 0
# 2                         1                 1
# 3                         0                 1
# 4                         0                 0
# ...                     ...               ...
# 1465                      0                 0
# 1466                      0                 0
# 1467                      0                 1
# 1468                      0                 0
# 1469                      0                 0
#
# [1470 rows x 39 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
data_attr['BusinessTravel'] = encoder.fit_transform(data_attr['BusinessTravel'])
data_attr['Department'] = encoder.fit_transform(data_attr['Department'])
data_attr['EducationField'] = encoder.fit_transform(data_attr['EducationField'])
data_attr['JobRole'] = encoder.fit_transform(data_attr['JobRole'])
data_attr
# Out:
#       Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41       Yes               2       1102           2                 1
# 1      49        No               1        279           1                 8
# 2      37       Yes               2       1373           1                 2
# 3      33        No               1       1392           1                 3
# 4      27        No               2        591           1                 2
# ...   ...       ...             ...        ...         ...               ...
# 1465   36        No               1        884           1                23
# 1466   39        No               2        613           1                 6
# 1467   27        No               2        155           1                 4
# 1468   49        No               1       1023           2                 2
# 1469   34        No               2        628           1                 8
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0             2               1              1               1  ...
# 1             1               1              1               2  ...
# 2             2               4              1               4  ...
# 3             4               1              1               5  ...
# 4             1               3              1               7  ...
# ...         ...             ...            ...             ...  ...
# 1465          2               3              1            2061  ...
# 1466          1               3              1            2062  ...
# 1467          3               1              1            2064  ...
# 1468          3               3              1            2065  ...
# 1469          3               3              1            2068  ...
#
#       TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                         0               1               6
# 1                         3               3              10
# 2                         3               3               0
# 3                         3               3               8
# 4                         3               3               2
# ...                     ...             ...             ...
# 1465                      3               3               5
# 1466                      5               3               7
# 1467                      0               3               6
# 1468                      3               2               9
# 1469                      3               4               4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# ...                  ...                      ...                   ...
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
#       Attrition_numeric Gender_numeric  MaritalStatus_numeric  \
# 0                     1              1                      1
# 1                     0              0                      0
# 2                     1              0                      1
# 3                     0              1                      0
# 4                     0              0                      0
# ...                 ...            ...                    ...
# 1465                  0              0                      0
# 1466                  0              0                      0
# 1467                  0              0                      0
# 1468                  0              0                      0
# 1469                  0              0                      0
#
#       OverTime_numeric
# 0                    1
# 1                    0
# 2                    1
# 3                    1
# 4                    0
# ...                ...
# 1465                 0
# 1466                 0
# 1467                 1
# 1468                 0
# 1469                 0
#
# [1470 rows x 39 columns]

# %%
data_attr.drop(['Attrition', 'DailyRate', 'EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours', 'StockOptionLevel','Gender','MaritalStatus','OverTime','BusinessTravel','TrainingTimesLastYear','NumCompaniesWorked','MonthlyRate',], axis=1, inplace=True)

# %%
data_attr.columns
# Out:
# Index(['Age', 'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MonthlyIncome', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'TotalWorkingYears',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition_numeric',
#        'Gender_numeric', 'MaritalStatus_numeric', 'OverTime_numeric'],
#       dtype='object')

# %%
Numerical_columns_update = ['Age', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MonthlyIncome', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition_numeric', 'Gender_numeric','MaritalStatus_numeric', 'OverTime_numeric']
core_new = data_attr[Numerical_columns_update].corr()

# %%
plt.figure(figsize=(34, 16))
sns.heatmap(core_new, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
data_attr.columns
# Out:
# Index(['Age', 'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MonthlyIncome', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'TotalWorkingYears',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition_numeric',
#        'Gender_numeric', 'MaritalStatus_numeric', 'OverTime_numeric'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from imblearn.combine import SMOTETomek

# %% [markdown]
#  Handling the Imbalanced dataset
# Note that we have a imbalanced dataset with majority of observations being of one type ('NO') in our case. In this dataset for example we have about 84 % of observations having 'No' and only 16 % of 'Yes' and hence this is an imbalanced dataset.
#
# To deal with such a imbalanced dataset we have to take certain measures, otherwise the performance of our model can be significantly affected. In this section I have discussed two approaches to curb such datasets.

# %%
X = data_attr.drop(['Attrition_numeric'], axis=1)
y = data_attr['Attrition_numeric']

# Apply SMOTETomek to the data
smote_tomek = SMOTETomek(sampling_strategy='auto', random_state=42)
X_new, y_new = smote_tomek.fit_resample(X, y)

# %%
X.shape, y.shape, X_new.shape, y_new.shape
# Out:
# ((1470, 24), (1470,), (2330, 24), (2330,))

# %% [markdown]
# # Building the model with logistic regression

# %%
X = data_attr.drop(['Attrition_numeric'], axis=1)
y = data_attr['Attrition_numeric']

# train and test the input_data
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.2, random_state=42)

# Create and fit a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

#Calculate accuracy on train and test
accuracy_train = accuracy_score(y_train, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

print(f"Accuracy on the training set: {accuracy_train:.4f}")
print(f"Accuracy on the testing set: {accuracy_test:.4f}")
# Out:
# Accuracy on the training set: 0.7049
# Accuracy on the testing set: 0.7124

# %% [markdown]
# # Building the model with KNeighborsClassifier

# %%
# train and test the input_data
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.2, random_state=42)

# Create and fit a the k value
k = 5  #
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)

# Make predictions on the test set
y_train_pred = knn.predict(X_train)
y_test_pred = knn.predict(X_test)

# Calculate accuracy on train and test
accuracy_train = accuracy_score(y_train, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

print(f"Accuracy on the training set: {accuracy_train:.4f}")
print(f"Accuracy on the testing set: {accuracy_test:.4f}")
# Out:
# Accuracy on the training set: 0.8256
# Accuracy on the testing set: 0.7382

# %%
# Building the model with GaussianNB

# %%
# train and test the input_data
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.2, random_state=42)

# Create and fit a Naive Bayes classifier
nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_train_pred = nb_classifier.predict(X_train)
y_test_pred = nb_classifier.predict(X_test)

# Calculate accuracy on train and test
accuracy_train = accuracy_score(y_train, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

print(f"Accuracy on the training set: {accuracy_train:.4f}")
print(f"Accuracy on the testing set: {accuracy_test:.4f}")
# Out:
# Accuracy on the training set: 0.7210
# Accuracy on the testing set: 0.6845

# %% [markdown]
# # Building the model with RandomForestClassifier

# %%
# train and test the input_data
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.2, random_state=42)

# Create and fit a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=50, random_state=42)
rf_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_train_pred = rf_classifier.predict(X_train)
y_test_pred = rf_classifier.predict(X_test)

# Calculate accuracy train and test
accuracy_train = accuracy_score(y_train, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

print(f"Accuracy on the training set: {accuracy_train:.4f}")
print(f"Accuracy on the testing set: {accuracy_test:.4f}")
# Out:
# Accuracy on the training set: 1.0000
# Accuracy on the testing set: 0.8927

# %% [markdown]
# # Building the model with XGBClassifier

# %%
#Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new , test_size=0.2, random_state=42)


model = XGBClassifier(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, random_state=42)
model.fit(X_train, y_train)


# Make predictions on the test set
y_train_pred = rf_classifier.predict(X_train)
y_test_pred = rf_classifier.predict(X_test)

# Calculate accuracy train and test
accuracy_train = accuracy_score(y_train, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

print(f"Accuracy on the training set: {accuracy_train:.4f}")
print(f"Accuracy on the testing set: {accuracy_test:.4f}")
# Out:
# Accuracy on the training set: 1.0000
# Accuracy on the testing set: 0.8927

# %% [markdown]
# # Hyperparameter Tuning
#  Create and train the final XGBoost model with the best hyperparameters

# %%
param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

xgb_class = XGBClassifier(objective='reg:squarederror', random_state=42)

grid_search = GridSearchCV(estimator=xgb_class, param_grid=param_grid, scoring='r2', cv=3)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')

# Make predictions with the best model
best_model = grid_search.best_estimator_
y_test_pred_best = best_model.predict(X_test)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 150}

# %%
# Create and train the final XGBoost model with the best hyperparameters
XGB_final_model = XGBClassifier(objective='reg:squarederror',
                               n_estimators=150,
                               learning_rate=0.1,
                               max_depth=5,
                               random_state=42)

XGB_final_model.fit(X_train, y_train)

# Make predictions on training and testing sets
y_train_pred = XGB_final_model.predict(X_train)
y_test_pred = XGB_final_model.predict(X_test)

# confusion matrix and classification report
print("Confusion Matrix:")
print(confusion_matrix(y_true=y_test, y_pred=y_test_pred))

print("\nClassification Report:")
print(classification_report(y_true=y_test, y_pred=y_test_pred))
# Out:
# Confusion Matrix:
# [[225  27]
#  [ 19 195]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       252
#            1       0.88      0.91      0.89       214
#
#     accuracy                           0.90       466
#    macro avg       0.90      0.90      0.90       466
# weighted avg       0.90      0.90      0.90       466
